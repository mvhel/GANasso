# %%
import argparse
import os
import random
from torch.autograd import Variable
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.nn.parallel
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.utils.data
import torchvision
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision import transforms
from torchvision.utils import save_image
import torchvision.datasets as dset
import torchvision.transforms as transforms
import torchvision.utils as vutils
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import HTML
from matplotlib.pyplot import imshow, imsave

# Set random seem for reproducibility
manualSeed = 1312
#manualSeed = random.randint(1, 10000) # use if you want new results
print("Random Seed: ", manualSeed)
random.seed(manualSeed)
torch.manual_seed(manualSeed)

print(torchvision.__version__)
# This is used to check if there are corrupted image files.

class ImageFolderWithPaths(datasets.ImageFolder):
    """Custom dataset that includes image file paths. Extends
    torchvision.datasets.ImageFolder
    """

    # override the __getitem__ method. this is the method dataloader calls
    def __getitem__(self, index):
        # this is what ImageFolder normally returns 
        original_tuple = super(ImageFolderWithPaths, self).__getitem__(index)
        # the image file path
        path = self.imgs[index][0]
        # make a new tuple that includes original and the path
        tuple_with_path = (original_tuple + (path,))
        return tuple_with_path


# instantiate the dataset and dataloader
transform=torchvision.transforms.Compose([
                                torchvision.transforms.Resize(64),
                                torchvision.transforms.ToTensor(),
                                torchvision.transforms.Normalize(
                                 (0.5,0.5,0.5), (0.5,0.5,0.5))])

data_dir = F"./Dog_images/Label4/"
dataset = ImageFolderWithPaths(data_dir, transform = transform)
print(dataset)# our custom dataset
dataloader = torch.utils.data.DataLoader(dataset)

# iterate over data
for inputs, labels, paths in dataloader:
    # use the above variables freely
    print(paths)
# Out:
# Random Seed:  1312
# 0.2.1
# Dataset ImageFolderWithPaths
#     Number of datapoints: 13398
#     Root Location: ./Dog_images/Label4/
#     Transforms (if any): Compose(
#                              Resize(size=64, interpolation=PIL.Image.BILINEAR)
#                              ToTensor()
#                              Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))
#                          )
#     Target Transforms (if any): None
# ('./Dog_images/Label4/abstract\\abstract (1).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (100).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (1000).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10000).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10001).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10002).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10003).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10004).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10005).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10006).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10007).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10008).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10009).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (1001).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10010).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10011).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10012).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10013).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10014).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10015).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10016).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10017).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10018).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10019).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (1002).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10020).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10021).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10022).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10023).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10024).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10025).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10026).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10027).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10028).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10029).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (1003).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10030).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10031).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10032).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10033).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10034).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10035).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10036).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10037).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10038).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10039).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (1004).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10040).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10041).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10042).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10043).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10044).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10045).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10046).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10047).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10048).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10049).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (1005).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10050).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10051).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10052).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10053).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10054).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10055).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10056).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10057).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10058).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10059).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (1006).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10060).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10061).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10062).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10063).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10064).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10065).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10066).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10067).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10068).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10069).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (1007).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10070).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10071).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10072).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10073).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10074).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10075).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10076).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10077).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10078).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10079).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (1008).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10080).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10081).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10082).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10083).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10084).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10085).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10086).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10087).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10088).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10089).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (1009).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10090).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10091).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10092).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10093).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10094).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10095).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10096).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10097).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10098).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10099).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (101).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (1010).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10100).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10101).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10102).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10103).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10104).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10105).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10106).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10107).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10108).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10109).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (1011).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10110).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10111).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10112).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10113).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10114).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10115).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10116).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10117).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10118).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10119).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (1012).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10120).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10121).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10122).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10123).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10124).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10125).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10126).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10127).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10128).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (10129).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (1013).jpg',)
# ('./Dog_images/Label4/abstract\\abstract (